# %% [markdown]
# <a href="https://colab.research.google.com/github/jojoshawer/girlsai/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()  # This will prompt you to upload the kaggle.json file
# Out:
#      <input type="file" id="files-0f6db04c-7097-493d-82f9-648b44964164" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0f6db04c-7097-493d-82f9-648b44964164">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.makedirs('/root/.kaggle/', exist_ok=True)  # Create the .kaggle directory
# !mv kaggle.json /root/.kaggle/  # Move the kaggle.json file to the .kaggle directory
# !chmod 600 /root/.kaggle/kaggle.json  # Change permissions

# %%
import os
os.makedirs('/root/.kaggle/', exist_ok=True)  # Create the .kaggle directory

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-10dd773b-a3c1-4289-b37b-a073c7578d5b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-10dd773b-a3c1-4289-b37b-a073c7578d5b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# Create the .kaggle directory
os.makedirs('/root/.kaggle/', exist_ok=True)

# Move the kaggle.json file to the .kaggle directory
# !mv kaggle.json /root/.kaggle/

# Change permissions
# !chmod 600 /root/.kaggle/kaggle.json

# %%
from google.colab import files
import pandas as pd

# Step 1: Upload the file
uploaded = files.upload()

# Step 2: Load the dataset
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Step 3: Display the first few rows of the dataset
df.head()
# Out:
#      <input type="file" id="files-48152fbe-df73-482c-bf23-e164b5e981a7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-48152fbe-df73-482c-bf23-e164b5e981a7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Importing necessary libraries
import pandas as pd

# Load the dataset (if you haven't done this yet)
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.columns.values
# Out:
# array(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'Churn'], dtype=object)

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.tail(10)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 7033          Yes                No     Fiber optic                   No  ...
# ...

# %%
print("\nUnique values for categorical columns:")
for column in df.select_dtypes(include=['object']).columns:
    print(f"{column}: {df[column].unique()[:5]}")  # Show first 5 unique values for brevity
# Out:
# Unique values for categorical columns:
# customerID: ['7590-VHVEG' '5575-GNVDE' '3668-QPYBK' '7795-CFOCW' '9237-HQITU']
# gender: ['Female' 'Male']
# Partner: ['Yes' 'No']
# Dependents: ['No' 'Yes']
# PhoneService: ['No' 'Yes']
# MultipleLines: ['No phone service' 'No' 'Yes']
# InternetService: ['DSL' 'Fiber optic' 'No']
# OnlineSecurity: ['No' 'Yes' 'No internet service']
# OnlineBackup: ['Yes' 'No' 'No internet service']
# DeviceProtection: ['No' 'Yes' 'No internet service']
# TechSupport: ['No' 'Yes' 'No internet service']
# StreamingTV: ['No' 'Yes' 'No internet service']
# StreamingMovies: ['No' 'Yes' 'No internet service']
# Contract: ['Month-to-month' 'One year' 'Two year']
# PaperlessBilling: ['Yes' 'No']
# PaymentMethod: ['Electronic check' 'Mailed check' 'Bank transfer (automatic)'
#  'Credit card (automatic)']
# TotalCharges: ['29.85' '1889.5' '108.15' '1840.75' '151.65']
# Churn: ['No' 'Yes']

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')

# Select the relevant columns for analysis
columns_of_interest = [
    'Churn', 'Contract', 'tenure',
    'InternetService', 'PhoneService',
    'TechSupport', 'OnlineSecurity',
    'DeviceProtection',
    'PaperlessBilling', 'PaymentMethod',
    'TotalCharges'
]

df_filtered = df[columns_of_interest].copy()  # Create a copy to avoid SettingWithCopyWarning

# Convert 'Churn' to binary numeric for analysis
df_filtered.loc[:, 'Churn'] = df_filtered['Churn'].map({'No': 0, 'Yes': 1})

# Make sure 'TotalCharges' is numeric
df_filtered.loc[:, 'TotalCharges'] = pd.to_numeric(df_filtered['TotalCharges'], errors='coerce')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
# Analyze the 'Churn' based on 'Contract' type
contract_analysis = df_filtered.groupby('Contract')['Churn'].mean().reset_index()
contract_analysis.columns = ['Contract', 'Churn Rate']
print("\nChurn Rate by Contract Type:")
print(contract_analysis)
# Out:
# Churn Rate by Contract Type:
#          Contract Churn Rate
# 0  Month-to-month   0.427097
# 1        One year   0.112695
# 2        Two year   0.028319

# %%
# Analyze 'Churn' based on 'tenure'
tenure_churn = df_filtered[['tenure', 'Churn']].groupby('tenure').mean().reset_index()
print("\nChurn Rate by Tenure in months:")
print(tenure_churn)
# Out:
# Churn Rate by Tenure in months:
#     tenure     Churn
# 0        0       0.0
# 1        1  0.619902
# 2        2  0.516807
# 3        3      0.47
# 4        4  0.471591
# ..     ...       ...
# 68      68      0.09
# 69      69  0.084211
# 70      70  0.092437
# 71      71  0.035294
# 72      72  0.016575
#
# [73 rows x 2 columns]

# %%
# Analyze 'Churn' based on 'InternetService'
internet_service_analysis = df_filtered.groupby('InternetService')['Churn'].mean().reset_index()
internet_service_analysis.columns = ['Internet Service', 'Churn Rate']
print("\nChurn Rate by Internet Service:")
print(internet_service_analysis)
# Out:
# Churn Rate by Internet Service:
#   Internet Service Churn Rate
# 0              DSL   0.189591
# 1      Fiber optic   0.418928
# 2               No    0.07405

# %%
# Analyze 'Churn' based on 'PhoneService'
phone_service_analysis = df_filtered.groupby('PhoneService')['Churn'].mean().reset_index()
phone_service_analysis.columns = ['Phone Service', 'Churn Rate']
print("\nChurn Rate by Phone Service:")
print(phone_service_analysis)
# Out:
# Churn Rate by Phone Service:
#   Phone Service Churn Rate
# 0            No   0.249267
# 1           Yes   0.267096

# %%
# Analyze 'Churn' based on 'TechSupport'
tech_support_analysis = df_filtered.groupby('TechSupport')['Churn'].mean().reset_index()
tech_support_analysis.columns = ['Tech Support', 'Churn Rate']
print("\nChurn Rate by Tech Support:")
print(tech_support_analysis)
# Out:
# Churn Rate by Tech Support:
#           Tech Support Churn Rate
# 0                   No   0.416355
# 1  No internet service    0.07405
# 2                  Yes   0.151663

# %%
# Analyze 'Churn' based on 'OnlineSecurity'
online_security_analysis = df_filtered.groupby('OnlineSecurity')['Churn'].mean().reset_index()
online_security_analysis.columns = ['Online Security', 'Churn Rate']
print("\nChurn Rate by Online Security:")
print(online_security_analysis)
# Out:
# Churn Rate by Online Security:
#        Online Security Churn Rate
# 0                   No   0.417667
# 1  No internet service    0.07405
# 2                  Yes   0.146112

# %%
# Analyze 'Churn' based on 'DeviceProtection'
device_protection_analysis = df_filtered.groupby('DeviceProtection')['Churn'].mean().reset_index()
device_protection_analysis.columns = ['Device Protection', 'Churn Rate']
print("\nChurn Rate by Device Protection:")
print(device_protection_analysis)
# Out:
# Churn Rate by Device Protection:
#      Device Protection Churn Rate
# 0                   No   0.391276
# 1  No internet service    0.07405
# 2                  Yes   0.225021

# %%
# Analyze 'Churn' based on 'PaperlessBilling'
paperless_billing_analysis = df_filtered.groupby('PaperlessBilling')['Churn'].mean().reset_index()
paperless_billing_analysis.columns = ['Paperless Billing', 'Churn Rate']
print("\nChurn Rate by Paperless Billing:")
print(paperless_billing_analysis)
# Out:
# Churn Rate by Paperless Billing:
#   Paperless Billing Churn Rate
# 0                No   0.163301
# 1               Yes   0.335651

# %%
# Analyze 'Churn' based on 'PaymentMethod'
payment_method_analysis = df_filtered.groupby('PaymentMethod')['Churn'].mean().reset_index()
payment_method_analysis.columns = ['Payment Method', 'Churn Rate']
print("\nChurn Rate by Payment Method:")
print(payment_method_analysis)
# Out:
# Churn Rate by Payment Method:
#               Payment Method Churn Rate
# 0  Bank transfer (automatic)   0.167098
# 1    Credit card (automatic)   0.152431
# 2           Electronic check   0.452854
# 3               Mailed check   0.191067

# %%
# Analyze 'Churn' based on 'TotalCharges' (as a numerical variable)
total_charges_analysis = df_filtered[['TotalCharges', 'Churn']].dropna()
correlation_total_charges = total_charges_analysis.corr().iloc[0, 1]  # Correlation between Churn and TotalCharges
print(f"\nCorrelation between Total Charges and Churn: {correlation_total_charges:.4f}")
# Out:
# Correlation between Total Charges and Churn: -0.1995

# %%
plt.figure(figsize=(6, 6))
labels =["Churn: Yes","Churn:No"]
values = [1869,5163]
labels_gender = ["F","M","F","M"]
sizes_gender = [939,930 , 2544,2619]
colors = ['#ff6066', '#66b3ff']
colors_gender = ['#a6cee3', '#fb9a99', '#b2df8a', '#fdbf6f']

explode = (0.3,0.3)
explode_gender = (0.1,0.1,0.1,0.1)
textprops = {"fontsize":15}
#Plot
plt.pie(values, labels=labels,autopct='%1.1f%%',pctdistance=1.08, labeldistance=0.8,colors=colors, startangle=90,frame=True, explode=explode,radius=10, textprops =textprops, counterclock = True, )
plt.pie(sizes_gender,labels=labels_gender,colors=colors_gender,startangle=90, explode=explode_gender,radius=7, textprops =textprops, counterclock = True, )
#Draw circle
centre_circle = plt.Circle((0,0),5,color='black', fc='white',linewidth=0)
fig = plt.gcf()
fig.gca().add_artist(centre_circle)

plt.title('Churn Distribution w.r.t Gender: Male(M), Female(F)', fontsize=15, y=1.1)

# show plot

plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Analyze Total Charges for churned customers only
plt.figure(figsize=(12, 8))  # Adjust size if 30x26 is too large for display
sns.boxplot(y='TotalCharges', data=churned_only)
plt.title('Total Charges for Churned Customers')
plt.ylabel('Total Charges')
plt.show()

# %%
import seaborn as sns

# Set context and font scale for better readability
sns.set_context("paper", font_scale=1.1)

# KDE plot for Monthly Charges by Churn status
ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'No')],
                 color="Red", fill=True)
ax = sns.kdeplot(df.MonthlyCharges[(df["Churn"] == 'Yes')],
                 ax=ax, color="Blue", fill=True)

# Customize the legend, labels, and title
ax.legend(["Not Churn", "Churn"], loc='upper right')
ax.set_ylabel('Density')
ax.set_xlabel('Monthly Charges')
ax.set_title('Distribution of Monthly Charges by Churn')
# Out:
# Text(0.5, 1.0, 'Distribution of Monthly Charges by Churn')

# %%
# Correlation heatmap for churned customers only
numerical_features_churned = churned_only.select_dtypes(include=['number'])
correlation_churned = numerical_features_churned.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_churned, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title('Correlation Heatmap for Churned Customers')
plt.show()

# %%
fig = px.box(df, x='Churn', y = 'tenure')

# Update yaxis properties
fig.update_yaxes(title_text='Tenure (Months)', row=1, col=1)
# Update xaxis properties
fig.update_xaxes(title_text='Churn', row=1, col=1)

# Update size and title
fig.update_layout(autosize=True, width=750, height=600,
    title_font=dict(size=25, family='Courier'),
    title='<b>Tenure vs Churn</b>',
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np # Import numpy

plt.figure(figsize=(25, 10))

corr = df.apply(lambda x: pd.factorize(x)[0]).corr()

mask = np.triu(np.ones_like(corr, dtype=bool))

ax = sns.heatmap(corr, mask=mask, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, linewidths=.2, cmap='coolwarm', vmin=-1, vmax=1)

# %%
import numpy as np
import pandas as pd

# Step 1: Define the states
states = ['Active', 'Churned']

# Step 2: Create the transition matrix
# Example transition probabilities
# Rows represent the current state, columns represent the next state
# P(Active to Active), P(Active to Churned), P(Churned to Active), P(Churned to Churned)
transition_matrix = np.array([[0.8, 0.2],  # Active
                              [0.3, 0.7]]) # Churned

# Step 3: Create a function to simulate the Markov Chain
def simulate_markov_chain(start_state, transition_matrix, n_steps):
    current_state = start_state
    states_history = [current_state]

    for _ in range(n_steps):
        if current_state == 'Active':
            current_state = np.random.choice(states, p=transition_matrix[0])
        else:
            current_state = np.random.choice(states, p=transition_matrix[1])
        states_history.append(current_state)

    return states_history

# Step 4: Simulate the Markov Chain for a specified number of steps
n_steps = 10  # For example, simulate for 10 periods
initial_state = 'Active'  # Start with an Active customer
result = simulate_markov_chain(initial_state, transition_matrix, n_steps)

# Step 5: Analyze the results
print("State transition history:")
print(result)

# Count occurrences of each state
state_counts = pd.Series(result).value_counts()
print("\nState counts:")
print(state_counts)

# Calculate the probabilities of being in each state after the simulation
state_probabilities = state_counts / len(result)
print("\nState probabilities:")
print(state_probabilities)
